    return {
        tuple(sorted((u, v)))
        for u, v, attrs in G.edges(data=True)
        if attrs.get("kind") == "hydrogen"
    }

h1 = hydrogen_edges(G_wt_atom)
h2 = hydrogen_edges(G2_atoms)

#print("Lost:",   h1 - h2)
#print("Gained:", h2 - h1)
#print("Same:",   h1 & h2)

# %%
# --- Your existing logic ---
h1 = hydrogen_edges(G_wt_residues)
h2 = hydrogen_edges(G2_residues)

lost_bonds = h1 - h2
gained_bonds = h2 - h1
#conserved_bonds = h1 & h2
conserved_bonds = []

# --- Call the function with the residue ID constraint ---
#display_bond_comparison(lost_bonds, gained_bonds, conserved_bonds, max_resi=240)

# %%
import networkx as nx
import pandas as pd
from typing import List, Tuple, Dict

def compare_residue_graphs(
    G_wt: nx.Graph,
    G_mut: nx.Graph
) -> pd.DataFrame:
    """
    Compare the wild-type and mutant residue graphs.
    Returns a DataFrame with columns:
      res1, res2, kind, status
    where status ∈ {"conserved","lost","gained"}.
    """
    # Extract labeled edges as (u,v,kind)
    def labeled_edges(G):
        return {(min(u,v), max(u,v), G[u][v]['kind']) for u,v in G.edges()}
    
    edges_wt = labeled_edges(G_wt)
    edges_mut = labeled_edges(G_mut)
    
    conserved = edges_wt & edges_mut
    lost = edges_wt - edges_mut
    gained = edges_mut - edges_wt
    
    records = []
    for u,v,kind in conserved:
        records.append((int(u), int(v), kind, 'conserved'))
    for u,v,kind in lost:
        records.append((int(u), int(v), kind, 'lost'))
    for u,v,kind in gained:
        records.append((int(u), int(v), kind, 'gained'))
    
    df = pd.DataFrame(records, columns=['res_id1','res_id2','kind','status'])
    return df

def hydrogen_edges_for_residue(
    G_res: nx.Graph,
    residue: str
) -> List[Tuple[str,str]]:
    """
    Return all hydrogen-bond edges adjacent to a given residue.
    Each edge returned as (residue, neighbor).
    """
    edges = []
    for nbr in G_res.neighbors(residue):
        data = G_res[residue][nbr]
        if data.get('kind') == 'hydrogen':
            edges.append((residue, nbr))
    return edges

def shortest_hydrogen_path(
    G_res: nx.Graph,
    start: str,
    end: str
) -> List[str]:
    """
    Compute the shortest path between two residues using only hydrogen bonds.
    Returns a list of residues along the path (including start and end).
    Raises NetworkXNoPath if none exists.
    """
    # Create subgraph of hydrogen edges only
    H = nx.Graph(((u,v) for u,v,d in G_res.edges(data=True) if d.get('kind')=='hydrogen'))
    path = nx.shortest_path(H, source=start, target=end)
    return path

# 2. Compare graphs
# df_comparison = compare_residue_graphs(G_wt, G_mut)
# print(df_comparison)

# 3. Hydrogen edges for residue 'A10' in mutant
# h_edges = hydrogen_edges_for_residue(G_mut, 'A10')
# print(h_edges)

# 4. Shortest hydrogen‐bond path from 'A10' to 'C50'
# try:
#     path = shortest_hydrogen_path(G_mut, 'A10', 'C50')
#     print("Shortest H-bond path:", path)
# except nx.NetworkXNoPath:
#     print("No hydrogen-bond path exists between A10 and C50.")

# %%
df_comparison = compare_residue_graphs(G_wt_residues, G2_residues)
df_comparison.head(10)
# Out:
#    res_id1  res_id2      kind     status
# 0      189      193  hydrogen  conserved
# 1      236       40  hydrogen  conserved
# 2      197      504  hydrogen  conserved
# 3      200      203  hydrogen  conserved
# 4      216      221  hydrogen  conserved
# 5      173      177  hydrogen  conserved
# 6      203      206  hydrogen  conserved
# 7        4        5  hydrogen  conserved
# 8       39       41  hydrogen  conserved
# 9       48       52  hydrogen  conserved

# %%
filtered_df = df_comparison[
    (df_comparison['status'] == 'lost') & 
    ((df_comparison['res_id1'] <= 240) & (df_comparison['res_id2'] <= 240))
]
filtered_df
# Out:
#      res_id1  res_id2      kind status
# 259      215       89  hydrogen   lost
# 269      197       86  hydrogen   lost
# 270       92       95  hydrogen   lost
# 279      204      207  hydrogen   lost
# 287       49       52  hydrogen   lost
# 291       12       82  hydrogen   lost
# 304      219       88  hydrogen   lost
# 305       13        3  hydrogen   lost
# 306       66       68  hydrogen   lost
# 311       10       82  hydrogen   lost
# 329       45       99  hydrogen   lost

# %%
filtered_df = df_comparison[
    (df_comparison['status'] == 'gained') & 
    ((df_comparison['res_id1'] <= 240) & (df_comparison['res_id2'] <= 240))
]
filtered_df
# Out:
#      res_id1  res_id2      kind  status
# 342      165      166  hydrogen  gained
# 343        8        9  hydrogen  gained
# 348      199      201  hydrogen  gained
# 349       88       88  hydrogen  gained
# 359      238      240  hydrogen  gained
# 374      201      203  hydrogen  gained
# 383      159      162  hydrogen  gained
# 384      235       40  hydrogen  gained
# 399       38       38  hydrogen  gained
# 402      215      220  hydrogen  gained
# 406      105      237  hydrogen  gained
# 409       13        4  hydrogen  gained
# 412      163      165  hydrogen  gained
# 414      122      125  hydrogen  gained
# 416       37       43  hydrogen  gained
# 417      101      105  hydrogen  gained
# 423       40       41  hydrogen  gained
# 425       40       43  hydrogen  gained
# 427      162      164  hydrogen  gained
# 430       76       77  hydrogen  gained

# %%
h_edges = hydrogen_edges_for_residue(G_wt_residues, '219')
print(h_edges)
# Out:
# [('219', '88'), ('219', '215'), ('219', '216'), ('219', '503')]

# %%
try:
    path = shortest_hydrogen_path(G_wt_residues, '88', '219')
    print("Shortest H-bond path:", path)
except nx.NetworkXNoPath:
    print("No hydrogen-bond path exists between 88 and 219.")
# Out:
# Shortest H-bond path: ['88', '219']

# %% [markdown]
# # Напишем проверку водородных связей для списка мутаций в одном мутанте

# %%
mutant_name = """
L/89/G P/93/V L/125/S C/146/G A/217/F I/224/Q
"""

# %%
mutants = mutant_name.split()
mutants
# Out:
# ['L/89/G', 'P/93/V', 'L/125/S', 'C/146/G', 'A/217/F', 'I/224/Q']

# %%
aa_sites = [site.split('/')[1] for site in mutants]
aa_sites
# Out:
# ['89', '93', '125', '146', '217', '224']

# %% [markdown]
# Кратчайшие пути до 219, 207, 215

# %%
for site in aa_sites:
    try:
        path = shortest_hydrogen_path(G_wt_residues, site, '219')
        print(f"Shortest H-bond path between {site} and 219:", path)
    except nx.NetworkXNoPath:
        print(f"No hydrogen-bond path exists between {site} and 219.")
# Out:
# Shortest H-bond path between 89 and 219: ['89', '215', '219']
# Shortest H-bond path between 93 and 219: ['93', '89', '215', '219']
# Shortest H-bond path between 125 and 219: ['125', '129', '137', '197', '207', '211', '215', '219']
# Shortest H-bond path between 146 and 219: ['146', '142', '138', '198', '195', '192', '188', '215', '219']
# Shortest H-bond path between 217 and 219: ['217', '213', '209', '212', '216', '219']
# Shortest H-bond path between 224 and 219: ['224', '220', '216', '219']

# %%
for site in aa_sites:
    try:
        path = shortest_hydrogen_path(G_wt_residues, site, '207')
        print(f"Shortest H-bond path between {site} and 207:", path)
    except nx.NetworkXNoPath:
        print(f"No hydrogen-bond path exists between {site} and 207.")
# Out:
# Shortest H-bond path between 89 and 207: ['89', '85', '504', '207']
# Shortest H-bond path between 93 and 207: ['93', '89', '85', '504', '207']
# Shortest H-bond path between 125 and 207: ['125', '129', '137', '197', '207']
# Shortest H-bond path between 146 and 207: ['146', '142', '138', '198', '195', '200', '203', '207']
# Shortest H-bond path between 217 and 207: ['217', '213', '209', '212', '208', '204', '207']
# Shortest H-bond path between 224 and 207: ['224', '220', '216', '212', '208', '204', '207']

# %%
for site in aa_sites:
    try:
        path = shortest_hydrogen_path(G_wt_residues, site, '215')
        print(f"Shortest H-bond path between {site} and 215:", path)
    except nx.NetworkXNoPath:
        print(f"No hydrogen-bond path exists between {site} and 215.")
# Out:
# Shortest H-bond path between 89 and 215: ['89', '215']
# Shortest H-bond path between 93 and 215: ['93', '89', '215']
# Shortest H-bond path between 125 and 215: ['125', '129', '137', '197', '207', '211', '215']
# Shortest H-bond path between 146 and 215: ['146', '142', '138', '198', '195', '192', '188', '215']
# Shortest H-bond path between 217 and 215: ['217', '213', '209', '212', '216', '219', '215']
# Shortest H-bond path between 224 and 215: ['224', '220', '216', '219', '215']

# %% [markdown]
# # Найдем различие в водородных связяъ для заданных мутаций + 219, 207, 215

# %%
filtered_df = df_comparison[
    (df_comparison['status'] == 'gained') & 
    (df_comparison['res_id1'].isin([int(s) for s in aa_sites] + [219, 207, 215]) |
     df_comparison['res_id2'].isin([int(s) for s in aa_sites] + [219, 207, 215])
    )
]
filtered_df
# Out:
#      res_id1  res_id2      kind  status
# 338      215      512  hydrogen  gained
# 344      207      506  hydrogen  gained
# 350      503       89  hydrogen  gained
# 389      215      507  hydrogen  gained
# 402      215      220  hydrogen  gained
# 407      219      507  hydrogen  gained
# 414      122      125  hydrogen  gained

# %%
filtered_df = df_comparison[
    (df_comparison['status'] == 'lost') & 
    (df_comparison['res_id1'].isin([int(s) for s in aa_sites] + [219, 207, 215]) |
     df_comparison['res_id2'].isin([int(s) for s in aa_sites] + [219, 207, 215])
    )
]
filtered_df
# Out:
#      res_id1  res_id2      kind status
# 259      215       89  hydrogen   lost
# 261      125      555  hydrogen   lost
# 279      204      207  hydrogen   lost
# 282      207      507  hydrogen   lost
# 299      215      503  hydrogen   lost
# 304      219       88  hydrogen   lost
# 313      215      510  hydrogen   lost
# 314      219      503  hydrogen   lost
# 333      215      502  hydrogen   lost
